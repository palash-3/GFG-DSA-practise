# %%
print(7/2) #true division
print(7//2) #floor division
print(-7//2) #floor division, vlaue rounds towards negative infinity
print(int(-7//3)) #when you want to round the vlaue toward zero
# Out:
# 3.5
# 3
# -4
# -3

# %%
print(7%-3)
# Out:
# -2

# %%
#ternary operation
a: int = 10
b: float = 5
print(type(b))

result = "a is big" if a>b else "b is big"
print(result)
# Out:
# <class 'int'>
# a is big

# %%
arr = [20,30,40,50,60]

for index, value in enumerate(arr):
    print(index, value)
# Out:
# 0 20
# 1 30
# 2 40
# 3 50
# 4 60
